# %%
import os
import numpy as np 
from PIL import Image
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split

# %%
def get_pixel_values(image_path):
    img = Image.open(image_path).convert('L').resize((48, 48))
    return list(img.getdata())


emotion_data_dir = '/kaggle/input/emotion-data/emotion_data'  
emotionList = [d for d in os.listdir(emotion_data_dir) if os.path.isdir(os.path.join(emotion_data_dir, d))]
emotionList.sort()  # Ensure consistent order
DigitAssigned = {emotion: idx for idx, emotion in enumerate(emotionList)}

no_of_images = 0
for emotion in emotionList:
    no_of_images += len(os.listdir(os.path.join(emotion_data_dir, emotion)))
no_of_images
# Out:
# 10382

# %%
import tensorflow as tf


def Emotion_Model(input_shape=(48, 48, 1)):
    # Input layer
    inputImg = tf.keras.layers.Input(shape=input_shape, name='input')

    # Convert grayscale to RGB by repeating the channel 3 times
    x_rgb = tf.keras.layers.Concatenate(axis=-1)([inputImg, inputImg, inputImg])
    
    # ResNet50 base 
    resnet_base = tf.keras.applications.ResNet50(
        weights='imagenet', include_top=False, input_shape=(48, 48, 3)
    )
    for layer in resnet_base.layers:
        layer.trainable = False
    
    resnet_features = resnet_base(x_rgb)
    resnet_features = tf.keras.layers.GlobalAveragePooling2D()(resnet_features)
    resnet_features = tf.keras.layers.Dense(256, activation='relu')(resnet_features)
    resnet_features = tf.keras.layers.Dropout(0.3)(resnet_features)


    x = tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu', padding='same')(inputImg)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    x = tf.keras.layers.Conv2D(64, kernel_size=3, activation='relu', padding='same')(x)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
    x = tf.keras.layers.Dropout(0.3)(x)

    custom_features = tf.keras.layers.Flatten()(x)
    custom_features = tf.keras.layers.Dense(256, activation='relu')(custom_features)
    custom_features = tf.keras.layers.Dropout(0.3)(custom_features)

    # Combine features
    combined = tf.keras.layers.Concatenate()([resnet_features, custom_features])
    combined = tf.keras.layers.Dense(256, activation='relu')(combined)
    combined = tf.keras.layers.Dropout(0.4)(combined)

    # Output layer
    num_classes = len(emotionList)
    output = tf.keras.layers.Dense(num_classes, activation='softmax', name='output')(combined)

    # Model
    model = tf.keras.models.Model(inputs=inputImg, outputs=output)
    model.summary()
    return model

# %%
#Training Data
all_image_pixel_values = []
all_emotion_labels = []
for emotion in emotionList:
    images = os.listdir(os.path.join(emotion_data_dir, emotion))
    image_paths = [os.path.join(emotion_data_dir, emotion, img) for img in images]
    image_pixel_values = [get_pixel_values(img_path) for img_path in image_paths]
    all_image_pixel_values.extend(image_pixel_values)
    all_emotion_labels.extend([DigitAssigned[emotion]] * len(image_pixel_values))

X_train, X_test, y_train, y_test = train_test_split(
    np.array(all_image_pixel_values), 
    np.array(all_emotion_labels), 
    test_size=0.2, 
    random_state=42
)

print("Training data shape:", X_train.shape)
print("Training labels shape:", y_train.shape)
print("Testing data shape:", X_test.shape)
print("Testing labels shape:", y_test.shape)
# Out:
# Training data shape: (8305, 2304)
# Training labels shape: (8305,)
# Testing data shape: (2077, 2304)
# Testing labels shape: (2077,)

# %%
#Dividing by 255 to normalize
X_train = X_train / 255.0
X_test = X_test / 255.0

#Reshaping the array
X_train = X_train.reshape(X_train.shape[0], 48, 48, 1)
X_test = X_test.reshape(X_test.shape[0], 48, 48, 1)

print("X_train shape after reshape:", X_train.shape)
print("X_test shape after reshape:", X_test.shape)

#One hot encoding
y_train = tf.keras.utils.to_categorical(y_train)
y_test = tf.keras.utils.to_categorical(y_test)

#Creating Validation Set
X_val, X_test, y_val, y_test = train_test_split(X_test, y_test, test_size=0.5, random_state=42)
# Out:
# X_train shape after reshape: (8305, 48, 48, 1)
# X_test shape after reshape: (2077, 48, 48, 1)

# %% [markdown]
# ## Data Augmentation

# %%
# Data Augmentation
from tensorflow.keras.preprocessing.image import ImageDataGenerator



train_datagen = ImageDataGenerator(
    rotation_range=20,           # Randomly rotate images by up to 20 degrees
    width_shift_range=0.1,       # Randomly shift images horizontally by up to 10%
    height_shift_range=0.1,      # Randomly shift images vertically by up to 10%
    shear_range=0.1,            # Shear transformations
    zoom_range=0.1,             # Random zoom
    horizontal_flip=True,        # Random horizontal flips
    fill_mode='nearest',         # Fill mode for newly created pixels
    brightness_range=[0.8, 1.2], # Random brightness adjustment
    channel_shift_range=0.1      # Random channel shifts
)


val_test_datagen = ImageDataGenerator()

train_datagen.fit(X_train)

# Create augmented training generator
batch_size = 64
train_generator = train_datagen.flow(X_train, y_train, batch_size=batch_size)
val_generator = val_test_datagen.flow(X_val, y_val, batch_size=batch_size)

# %%
checkpointer = [
    tf.keras.callbacks.EarlyStopping(monitor='val_accuracy', verbose=1, restore_best_weights=True, mode="max", patience=100),
    tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor="val_accuracy", verbose=1, save_best_only=True, mode="max")
]

#Model Compilation
model = Emotion_Model()
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001)  # Lower learning rate for transfer learning
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

#Training the Model
ModelHistory = model.fit(
    X_train, y_train,
    epochs=100,  # Reduced epochs since we're using pre-trained models
    batch_size=32,
    verbose=1,
    callbacks=checkpointer,
    validation_data=(X_val, y_val)
)
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input (InputLayer)        │ (None, 48, 48, 1)      │              0 │ -                      │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_5 (Conv2D)         │ (None, 48, 48, 32)     │            320 │ input[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_4     │ (None, 48, 48, 32)     │            128 │ conv2d_5[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_3           │ (None, 24, 24, 32)     │              0 │ batch_normalization_4… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_8 (Dropout)       │ (None, 24, 24, 32)     │              0 │ max_pooling2d_3[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ conv2d_6 (Conv2D)         │ (None, 24, 24, 64)     │         18,496 │ dropout_8[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ batch_normalization_5     │ (None, 24, 24, 64)     │            256 │ conv2d_6[0][0]         │
# │ (BatchNormalization)      │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_3             │ (None, 48, 48, 3)      │              0 │ input[0][0],           │
# │ (Concatenate)             │                        │                │ input[0][0],           │
# │                           │                        │                │ input[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ max_pooling2d_4           │ (None, 12, 12, 64)     │              0 │ batch_normalization_5… │
# │ (MaxPooling2D)            │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ resnet50 (Functional)     │ (None, 2, 2, 2048)     │     23,587,712 │ concatenate_3[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_9 (Dropout)       │ (None, 12, 12, 64)     │              0 │ max_pooling2d_4[0][0]  │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ global_average_pooling2d… │ (None, 2048)           │              0 │ resnet50[0][0]         │
# │ (GlobalAveragePooling2D)  │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten_1 (Flatten)       │ (None, 9216)           │              0 │ dropout_9[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_4 (Dense)           │ (None, 256)            │        524,544 │ global_average_poolin… │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_5 (Dense)           │ (None, 256)            │      2,359,552 │ flatten_1[0][0]        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_7 (Dropout)       │ (None, 256)            │              0 │ dense_4[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_10 (Dropout)      │ (None, 256)            │              0 │ dense_5[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ concatenate_4             │ (None, 512)            │              0 │ dropout_7[0][0],       │
# │ (Concatenate)             │                        │                │ dropout_10[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_6 (Dense)           │ (None, 256)            │        131,328 │ concatenate_4[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout_11 (Dropout)      │ (None, 256)            │              0 │ dense_6[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ output (Dense)            │ (None, 6)              │          1,542 │ dropout_11[0][0]       │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 26,623,878 (101.56 MB)
#  Trainable params: 3,035,974 (11.58 MB)
#  Non-trainable params: 23,587,904 (89.98 MB)
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1750819708.611432      94 service.cc:148] XLA service 0x78e634058450 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1750819708.612164      94 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1750819710.393605      94 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   9/260 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.1290 - loss: 3.6050
# I0000 00:00:1750819716.645529      94 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.2368 - loss: 2.1408
# Epoch 1: val_accuracy improved from -inf to 0.21195, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 39s 69ms/step - accuracy: 0.2369 - loss: 2.1397 - val_accuracy: 0.2119 - val_loss: 1.8689
# Epoch 2/100
# 258/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3247 - loss: 1.6105
# Epoch 2: val_accuracy improved from 0.21195 to 0.41426, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.3247 - loss: 1.6103 - val_accuracy: 0.4143 - val_loss: 1.4808
# Epoch 3/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3651 - loss: 1.5390
# Epoch 3: val_accuracy improved from 0.41426 to 0.43834, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.3651 - loss: 1.5387 - val_accuracy: 0.4383 - val_loss: 1.3776
# Epoch 4/100
# 258/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.3845 - loss: 1.4884
# Epoch 4: val_accuracy improved from 0.43834 to 0.46146, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.3845 - loss: 1.4882 - val_accuracy: 0.4615 - val_loss: 1.3279
# Epoch 5/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4051 - loss: 1.4446
# Epoch 5: val_accuracy improved from 0.46146 to 0.47495, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.4051 - loss: 1.4446 - val_accuracy: 0.4750 - val_loss: 1.2876
# Epoch 6/100
# 257/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4334 - loss: 1.3779
# Epoch 6: val_accuracy improved from 0.47495 to 0.48073, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.4335 - loss: 1.3778 - val_accuracy: 0.4807 - val_loss: 1.2550
# Epoch 7/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4566 - loss: 1.3243
# Epoch 7: val_accuracy improved from 0.48073 to 0.49807, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.4566 - loss: 1.3244 - val_accuracy: 0.4981 - val_loss: 1.2128
# Epoch 8/100
# 259/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4702 - loss: 1.2997
# Epoch 8: val_accuracy improved from 0.49807 to 0.51830, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.4702 - loss: 1.2997 - val_accuracy: 0.5183 - val_loss: 1.1727
# Epoch 9/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4868 - loss: 1.2606
# Epoch 9: val_accuracy improved from 0.51830 to 0.52890, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.4870 - loss: 1.2604 - val_accuracy: 0.5289 - val_loss: 1.1609
# Epoch 10/100
# 257/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5114 - loss: 1.1991
# Epoch 10: val_accuracy improved from 0.52890 to 0.53565, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.5115 - loss: 1.1991 - val_accuracy: 0.5356 - val_loss: 1.1391
# Epoch 11/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5349 - loss: 1.1590
# Epoch 11: val_accuracy improved from 0.53565 to 0.54046, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.5348 - loss: 1.1591 - val_accuracy: 0.5405 - val_loss: 1.1384
# Epoch 12/100
# 258/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5569 - loss: 1.1258
# Epoch 12: val_accuracy improved from 0.54046 to 0.56262, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.5568 - loss: 1.1258 - val_accuracy: 0.5626 - val_loss: 1.1058
# Epoch 13/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5628 - loss: 1.0973
# Epoch 13: val_accuracy improved from 0.56262 to 0.56840, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.5628 - loss: 1.0973 - val_accuracy: 0.5684 - val_loss: 1.0884
# Epoch 14/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5825 - loss: 1.0523
# Epoch 14: val_accuracy improved from 0.56840 to 0.58285, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.5824 - loss: 1.0524 - val_accuracy: 0.5829 - val_loss: 1.0639
# Epoch 15/100
# 257/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6022 - loss: 1.0130
# Epoch 15: val_accuracy improved from 0.58285 to 0.59249, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 5s 18ms/step - accuracy: 0.6022 - loss: 1.0132 - val_accuracy: 0.5925 - val_loss: 1.0454
# Epoch 16/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6133 - loss: 1.0051
# Epoch 16: val_accuracy improved from 0.59249 to 0.59538, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.6133 - loss: 1.0050 - val_accuracy: 0.5954 - val_loss: 1.0334
# Epoch 17/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.6329 - loss: 0.9451
# Epoch 17: val_accuracy did not improve from 0.59538
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6328 - loss: 0.9450 - val_accuracy: 0.5867 - val_loss: 1.0801
# Epoch 18/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6468 - loss: 0.9114
# Epoch 18: val_accuracy improved from 0.59538 to 0.62717, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.6468 - loss: 0.9116 - val_accuracy: 0.6272 - val_loss: 1.0023
# Epoch 19/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6841 - loss: 0.8309
# Epoch 19: val_accuracy did not improve from 0.62717
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6840 - loss: 0.8310 - val_accuracy: 0.6214 - val_loss: 1.0232
# Epoch 20/100
# 258/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6867 - loss: 0.8290
# Epoch 20: val_accuracy did not improve from 0.62717
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.6866 - loss: 0.8291 - val_accuracy: 0.6040 - val_loss: 1.0683
# Epoch 21/100
# 259/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7030 - loss: 0.7932
# Epoch 21: val_accuracy improved from 0.62717 to 0.63487, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.7030 - loss: 0.7932 - val_accuracy: 0.6349 - val_loss: 0.9909
# Epoch 22/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7076 - loss: 0.7847
# Epoch 22: val_accuracy improved from 0.63487 to 0.65511, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.7076 - loss: 0.7847 - val_accuracy: 0.6551 - val_loss: 0.9291
# Epoch 23/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7266 - loss: 0.7290
# Epoch 23: val_accuracy did not improve from 0.65511
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.7264 - loss: 0.7293 - val_accuracy: 0.6503 - val_loss: 1.0145
# Epoch 24/100
# 257/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7391 - loss: 0.6849
# Epoch 24: val_accuracy improved from 0.65511 to 0.66185, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.7390 - loss: 0.6852 - val_accuracy: 0.6618 - val_loss: 0.9440
# Epoch 25/100
# 257/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.7358 - loss: 0.6831
# Epoch 25: val_accuracy improved from 0.66185 to 0.66763, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.
val_accuracy did not improve from 0.74181
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9540 - loss: 0.1320 - val_accuracy: 0.7274 - val_loss: 1.2890
# Epoch 84/100
# 257/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9566 - loss: 0.1254
# Epoch 84: val_accuracy did not improve from 0.74181
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9566 - loss: 0.1253 - val_accuracy: 0.7370 - val_loss: 1.4440
# Epoch 85/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9619 - loss: 0.1185
# Epoch 85: val_accuracy improved from 0.74181 to 0.74470, saving model to best_model.h5
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 17ms/step - accuracy: 0.9619 - loss: 0.1184 - val_accuracy: 0.7447 - val_loss: 1.3282
# Epoch 86/100
# 258/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9592 - loss: 0.1143
# Epoch 86: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9592 - loss: 0.1144 - val_accuracy: 0.7437 - val_loss: 1.3864
# Epoch 87/100
# 259/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9571 - loss: 0.1192
# Epoch 87: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9571 - loss: 0.1192 - val_accuracy: 0.7158 - val_loss: 1.5581
# Epoch 88/100
# 258/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9559 - loss: 0.1206
# Epoch 88: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9559 - loss: 0.1206 - val_accuracy: 0.7139 - val_loss: 1.2561
# Epoch 89/100
# 258/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9586 - loss: 0.1186
# Epoch 89: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9586 - loss: 0.1186 - val_accuracy: 0.7081 - val_loss: 1.7426
# Epoch 90/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9613 - loss: 0.1212
# Epoch 90: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9613 - loss: 0.1212 - val_accuracy: 0.7254 - val_loss: 1.5969
# Epoch 91/100
# 259/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9561 - loss: 0.1394
# Epoch 91: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9561 - loss: 0.1393 - val_accuracy: 0.7081 - val_loss: 1.7136
# Epoch 92/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9646 - loss: 0.0992
# Epoch 92: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step - accuracy: 0.9647 - loss: 0.0992 - val_accuracy: 0.7370 - val_loss: 1.2481
# Epoch 93/100
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9628 - loss: 0.1036
# Epoch 93: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9627 - loss: 0.1036 - val_accuracy: 0.7177 - val_loss: 1.6505
# Epoch 94/100
# 258/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9597 - loss: 0.1213
# Epoch 94: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9597 - loss: 0.1213 - val_accuracy: 0.7062 - val_loss: 1.8061
# Epoch 95/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9640 - loss: 0.1045
# Epoch 95: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9640 - loss: 0.1045 - val_accuracy: 0.7274 - val_loss: 1.5675
# Epoch 96/100
# 258/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9614 - loss: 0.1077
# Epoch 96: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9614 - loss: 0.1077 - val_accuracy: 0.7081 - val_loss: 1.7421
# Epoch 97/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9569 - loss: 0.1185
# Epoch 97: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9570 - loss: 0.1183 - val_accuracy: 0.7177 - val_loss: 1.2899
# Epoch 98/100
# 258/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9671 - loss: 0.0922
# Epoch 98: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9671 - loss: 0.0922 - val_accuracy: 0.7235 - val_loss: 1.2169
# Epoch 99/100
# 256/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9695 - loss: 0.0924
# Epoch 99: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9695 - loss: 0.0926 - val_accuracy: 0.6936 - val_loss: 2.0312
# Epoch 100/100
# 257/260 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9649 - loss: 0.0995
# Epoch 100: val_accuracy did not improve from 0.74470
# 260/260 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step - accuracy: 0.9649 - loss: 0.0995 - val_accuracy: 0.7418 - val_loss: 1.6026
# Restoring model weights from the end of the best epoch: 85.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, auc
from sklearn.preprocessing import label_binarize
import seaborn as sns

# Taller figure for vertical alignment
plt.figure(figsize=(10,14))

# --- Accuracy Plot (Top) ---
plt.subplot(2, 1, 1)
plt.plot(ModelHistory.history['accuracy'], label='Train Accuracy', linewidth=3)
plt.plot(ModelHistory.history['val_accuracy'], label='Validation Accuracy', linewidth=3)
plt.title('Model Accuracy', fontsize=36)
plt.xlabel('Epoch', fontsize=32)
plt.ylabel('Accuracy', fontsize=32)
plt.legend(loc='lower right', fontsize=28)
plt.xticks(fontsize=26)2
plt.yticks(fontsize=26)
plt.grid(True)

# --- Loss Plot (Bottom) ---
plt.subplot(2, 1, 2)
plt.plot(ModelHistory.history['loss'], label='Train Loss', linewidth=3)
plt.plot(ModelHistory.history['val_loss'], label='Validation Loss', linewidth=3)
plt.title('Model Loss', fontsize=36)
plt.xlabel('Epoch', fontsize=32)
plt.ylabel('Loss', fontsize=32)
plt.legend(loc='upper right', fontsize=28)
plt.xticks(fontsize=26)
plt.yticks(fontsize=26)
plt.grid(True)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Step 1: Predict class probabilities and predicted labels
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)
y_true = np.argmax(y_test, axis=1)  # <-- This line defines y_true properly

# Step 2: Classification report
print("\nClassification Report:\n")
print(classification_report(y_true, y_pred, target_names=emotionList))

# Step 3: Confusion matrix
cm = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=emotionList, yticklabels=emotionList, annot_kws={"size":22})
plt.title('Confusion Matrix', fontsize=26)
plt.xlabel('Predicted Label', fontsize=22)
plt.ylabel('True Label', fontsize=22)
plt.xticks(fontsize=18, rotation=45)
plt.yticks(fontsize=18, rotation=0)
plt.tight_layout()
plt.show()

# Step 4: Multi-class ROC curve
# Binarize y_true
y_test_bin = label_binarize(y_true, classes=list(range(len(emotionList))))
n_classes = y_test_bin.shape[1]

# Compute ROC curve and AUC for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_probs[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Plot all ROC curves
plt.figure(figsize=(14, 10))
colors = plt.cm.get_cmap('tab10', n_classes)

for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=3, label=f'{emotionList[i]} (AUC = {roc_auc[i]:.2f})')

plt.plot([0, 1], [0, 1], 'k--', lw=2)
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('False Positive Rate', fontsize=28)
plt.ylabel('True Positive Rate', fontsize=28)
plt.title('Multi-Class ROC Curve', fontsize=34)
plt.legend(loc='lower right', fontsize=22)  # ← Increased font size here
plt.xticks(fontsize=22)
plt.yticks(fontsize=22)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 11s 196ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#      boredom       0.66      0.61      0.63       175
#      confuse       0.68      0.56      0.61       172
#        focus       0.75      0.68      0.72       202
#   frustrated       0.71      0.78      0.74       169
#       sleepy       0.67      0.85      0.75       160
#      yawning       0.92      0.94      0.93       161
#
#     accuracy                           0.73      1039
#    macro avg       0.73      0.74      0.73      1039
# weighted avg       0.73      0.73      0.73      1039
# /tmp/ipykernel_35/1665985155.py:38: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap(obj)`` instead.
#   colors = plt.cm.get_cmap('tab10', n_classes)

# %%
import time
import numpy as np
import subprocess

# --- Timing the prediction ---
start_time = time.time()

# Run prediction
_ = model.predict(X_test)

end_time = time.time()
elapsed_time = end_time - start_time
num_images = X_test.shape[0]

# --- Calculate performance metrics ---
images_per_second = num_images / elapsed_time
avg_prediction_time = elapsed_time / num_images

print(f"\n📊 Total Images: {num_images}")
print(f"⏱️ Total Prediction Time: {elapsed_time:.4f} seconds")
print(f"⚡ Images per Second (Throughput): {images_per_second:.2f}")
print(f"🧠 Average Time per Image: {avg_prediction_time:.4f} seconds")

# --- GPU Power Usage using nvidia-smi ---
print("\n🖥️ Fetching GPU usage details...\n")

try:
    # Use nvidia-smi to get real-time power and GPU utilization
    gpu_stats = subprocess.check_output(
        ["nvidia-smi", "--query-gpu=power.draw,utilization.gpu,memory.used,memory.total", 
         "--format=csv,noheader,nounits"]
    )
    gpu_stats = gpu_stats.decode("utf-8").strip().split('\n')[0]
    power_draw, gpu_util, mem_used, mem_total = map(float, gpu_stats.split(', '))
    
    print(f"🔋 GPU Power Draw: {power_draw} W")
    print(f"🚀 GPU Utilization: {gpu_util}%")
    print(f"📦 GPU Memory Used: {mem_used} MiB / {mem_total} MiB")

except Exception as e:
    print("❌ Unable to fetch GPU details. Error:", str(e))
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
#
# 📊 Total Images: 1039
# ⏱️ Total Prediction Time: 0.4120 seconds
# ⚡ Images per Second (Throughput): 2521.72
# 🧠 Average Time per Image: 0.0004 seconds
#
# 🖥️ Fetching GPU usage details...
#
# 🔋 GPU Power Draw: 45.44 W
# 🚀 GPU Utilization: 52.0%
# 📦 GPU Memory Used: 3345.0 MiB / 16384.0 MiB
