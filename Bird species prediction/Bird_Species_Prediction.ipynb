# %% [markdown]
# # Bird Species Prediction

# %% [markdown]
# In this project we will create a Convolutional Neural Network which will be able to predict species of the bird. We will use different layers and other hyperparameters for building, training and testing this multiclass classifictaion model. We will be using keras for this project.

# %%
# Library imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
from os import listdir
from sklearn.preprocessing import  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split

# %% [markdown]
# dataset link - https://drive.google.com/file/d/1-h_HGhWJ-7UiOvKrrYwhmUvW1mVDgMJ4/view?usp=sharing

# %% [markdown]
# We will start by importing some required libraries.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "Data/Bird Speciees Dataset/AMERICAN GOLDFINCH"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)
    plt.ylabel(rand_img.shape[0], fontsize = 10)

# %% [markdown]
# Let's visualize some of the bird images that we will be working on. Also we will observe x and y dimensions of the image.

# %%
dir = "Data/Bird Speciees Dataset"
root_dir = listdir(dir)
image_list, label_list = [], []

# %% [markdown]
# Setting the root directory for the dataset and storing all the floders name of the dataset. We will also create 2 empty list for image and lables.

# %%
# Reading and converting image to numpy array
for directory in root_dir:
  for files in listdir(f"{dir}/{directory}"):
    image_path = f"{dir}/{directory}/{files}"
    image = cv2.imread(image_path)
    image = img_to_array(image)
    image_list.append(image)
    label_list.append(directory)

# %% [markdown]
# Next we will read all the images and convert it into array and appending the list created above with the image and its label.

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts
# Out:
# AMERICAN GOLDFINCH    143
# EMPEROR PENGUIN       139
# DOWNY WOODPECKER      137
# FLAMINGO              132
# CARMINE BEE-EATER     131
# BARN OWL              129
# Name: count, dtype: int64

# %% [markdown]
# Check for class imbalance.

# %%
# Storing number of classes
num_classes = len(label_counts)
num_classes
# Out:
# 6

# %% [markdown]
# Next we will find out the number of classes that we will be working on.

# %%
# Checking input image shape
image_list[0].shape
# Out:
# (224, 224, 3)

# %% [markdown]
# Checking the size of the single image.

# %%
# Checking labels shape 
label_list = np.array(label_list)
label_list.shape
# Out:
# (811,)

# %% [markdown]
# Checking the shape of image labels which will be equal to the number of images we are going to work with.

# %%
# Splitting dataset
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# Now we will split the data into training and testing using train_test_split() of sklearn.

# %%
# Normalize and reshape data
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 224,224,3)
x_test = x_test.reshape( -1, 224,224,3)

# %% [markdown]
# Next we will normalize the images by dividing them with 255. Also, we will reshape x_train and x_test.

# %%
# Label binarizing
lb = LabelBinarizer()
y_train = lb.fit_transform(y_train)
y_test = lb.fit_transform(y_test)
print(lb.classes_)
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']

# %% [markdown]
# Next we will use label binarizer to one hot encode our y data. We will also print the sequence of the classes.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %% [markdown]
# Now we will split the training data to validation and training data.

# %%
# Building model architecture
model = Sequential()
model.add(Conv2D(8, (3, 3), padding="same",input_shape=(224,224,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(32, activation="relu"))
model.add(Dense(num_classes, activation="softmax"))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 8)       224
#
#  max_pooling2d (MaxPooling2  (None, 74, 74, 8)         0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 74, 74, 16)        1168
#
#  max_pooling2d_1 (MaxPoolin  (None, 37, 37, 16)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 37, 37, 32)        4640
#
#  max_pooling2d_2 (MaxPoolin  (None, 18, 18, 32)        0
#  g2D)
#
#  flatten (Flatten)           (None, 10368)             0
#
#  dense (Dense)               (None, 32)                331808
#
#  dense_1 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 338038 (1.29 MB)
# Trainable params: 338038 (1.29 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Next we will create a network architecture for the model. We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel). In the last layer we will use softmax as the activation function because it is a multi class classification problem.

# %%
# Compiling model
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0005),metrics=['accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.

# %% [markdown]
# While compiling the model we need to set the type of loss which will be Categorical Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
# Training the model
epochs = 50
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 5/5 [==============================] - 3s 372ms/step - loss: 1.8629 - accuracy: 0.1834 - val_loss: 1.7388 - val_accuracy: 0.2231
# Epoch 2/50
# 5/5 [==============================] - 2s 326ms/step - loss: 1.7276 - accuracy: 0.2066 - val_loss: 1.6983 - val_accuracy: 0.2769
# Epoch 3/50
# 5/5 [==============================] - 2s 317ms/step - loss: 1.6339 - accuracy: 0.3571 - val_loss: 1.6174 - val_accuracy: 0.3462
# Epoch 4/50
# 5/5 [==============================] - 2s 343ms/step - loss: 1.5455 - accuracy: 0.3552 - val_loss: 1.5431 - val_accuracy: 0.3385
# Epoch 5/50
# 5/5 [==============================] - 2s 316ms/step - loss: 1.4436 - accuracy: 0.4459 - val_loss: 1.4616 - val_accuracy: 0.4231
# Epoch 6/50
# 5/5 [==============================] - 2s 339ms/step - loss: 1.3681 - accuracy: 0.4498 - val_loss: 1.4192 - val_accuracy: 0.4615
# Epoch 7/50
# 5/5 [==============================] - 2s 327ms/step - loss: 1.2719 - accuracy: 0.5116 - val_loss: 1.3723 - val_accuracy: 0.4385
# Epoch 8/50
# 5/5 [==============================] - 2s 348ms/step - loss: 1.2567 - accuracy: 0.4653 - val_loss: 1.2945 - val_accuracy: 0.4462
# Epoch 9/50
# 5/5 [==============================] - 2s 325ms/step - loss: 1.2031 - accuracy: 0.5270 - val_loss: 1.2233 - val_accuracy: 0.4846
# Epoch 10/50
# 5/5 [==============================] - 2s 327ms/step - loss: 1.1105 - accuracy: 0.5618 - val_loss: 1.2341 - val_accuracy: 0.5385
# Epoch 11/50
# 5/5 [==============================] - 2s 341ms/step - loss: 1.0633 - accuracy: 0.6158 - val_loss: 1.1820 - val_accuracy: 0.5308
# Epoch 12/50
# 5/5 [==============================] - 2s 325ms/step - loss: 0.9799 - accuracy: 0.6680 - val_loss: 1.1160 - val_accuracy: 0.5615
# Epoch 13/50
# 5/5 [==============================] - 2s 377ms/step - loss: 0.8710 - accuracy: 0.7239 - val_loss: 1.0170 - val_accuracy: 0.6615
# Epoch 14/50
# 5/5 [==============================] - 2s 328ms/step - loss: 0.8014 - accuracy: 0.7876 - val_loss: 0.9588 - val_accuracy: 0.7077
# Epoch 15/50
# 5/5 [==============================] - 2s 319ms/step - loss: 0.7599 - accuracy: 0.7876 - val_loss: 0.8912 - val_accuracy: 0.7077
# Epoch 16/50
# 5/5 [==============================] - 2s 339ms/step - loss: 0.7194 - accuracy: 0.8012 - val_loss: 0.8555 - val_accuracy: 0.7231
# Epoch 17/50
# 5/5 [==============================] - 2s 347ms/step - loss: 0.7420 - accuracy: 0.7587 - val_loss: 0.8417 - val_accuracy: 0.7462
# Epoch 18/50
# 5/5 [==============================] - 2s 443ms/step - loss: 0.5919 - accuracy: 0.8301 - val_loss: 0.8450 - val_accuracy: 0.6769
# Epoch 19/50
# 5/5 [==============================] - 2s 394ms/step - loss: 0.5787 - accuracy: 0.8456 - val_loss: 0.7254 - val_accuracy: 0.7846
# Epoch 20/50
# 5/5 [==============================] - 2s 338ms/step - loss: 0.4981 - accuracy: 0.8591 - val_loss: 0.7560 - val_accuracy: 0.7385
# Epoch 21/50
# 5/5 [==============================] - 2s 336ms/step - loss: 0.4746 - accuracy: 0.8475 - val_loss: 0.6835 - val_accuracy: 0.7846
# Epoch 22/50
# 5/5 [==============================] - 2s 333ms/step - loss: 0.4514 - accuracy: 0.8726 - val_loss: 0.6693 - val_accuracy: 0.7846
# Epoch 23/50
# 5/5 [==============================] - 2s 331ms/step - loss: 0.4244 - accuracy: 0.8726 - val_loss: 0.7287 - val_accuracy: 0.7077
# Epoch 24/50
# 5/5 [==============================] - 2s 339ms/step - loss: 0.3952 - accuracy: 0.8784 - val_loss: 0.6077 - val_accuracy: 0.7923
# Epoch 25/50
# 5/5 [==============================] - 2s 346ms/step - loss: 0.3753 - accuracy: 0.8919 - val_loss: 0.6257 - val_accuracy: 0.7846
# Epoch 26/50
# 5/5 [==============================] - 2s 340ms/step - loss: 0.3893 - accuracy: 0.8977 - val_loss: 0.6588 - val_accuracy: 0.8077
# Epoch 27/50
# 5/5 [==============================] - 2s 347ms/step - loss: 0.3638 - accuracy: 0.8842 - val_loss: 0.7083 - val_accuracy: 0.7692
# Epoch 28/50
# 5/5 [==============================] - 2s 341ms/step - loss: 0.3319 - accuracy: 0.9035 - val_loss: 0.5637 - val_accuracy: 0.8077
# Epoch 29/50
# 5/5 [==============================] - 2s 346ms/step - loss: 0.2768 - accuracy: 0.9363 - val_loss: 0.5495 - val_accuracy: 0.8231
# Epoch 30/50
# 5/5 [==============================] - 2s 343ms/step - loss: 0.2578 - accuracy: 0.9382 - val_loss: 0.5601 - val_accuracy: 0.8077
# Epoch 31/50
# 5/5 [==============================] - 2s 357ms/step - loss: 0.2876 - accuracy: 0.9131 - val_loss: 0.5509 - val_accuracy: 0.8154
# Epoch 32/50
# 5/5 [==============================] - 2s 351ms/step - loss: 0.2583 - accuracy: 0.9266 - val_loss: 0.6144 - val_accuracy: 0.7923
# Epoch 33/50
# 5/5 [==============================] - 2s 445ms/step - loss: 0.2344 - accuracy: 0.9324 - val_loss: 0.5391 - val_accuracy: 0.8154
# Epoch 34/50
# 5/5 [==============================] - 2s 485ms/step - loss: 0.2120 - accuracy: 0.9440 - val_loss: 0.5339 - val_accuracy: 0.8154
# Epoch 35/50
# 5/5 [==============================] - 2s 488ms/step - loss: 0.1919 - accuracy: 0.9479 - val_loss: 0.5600 - val_accuracy: 0.8308
# Epoch 36/50
# 5/5 [==============================] - 2s 397ms/step - loss: 0.2020 - accuracy: 0.9402 - val_loss: 0.5137 - val_accuracy: 0.8077
# Epoch 37/50
# 5/5 [==============================] - 2s 380ms/step - loss: 0.1866 - accuracy: 0.9498 - val_loss: 0.5008 - val_accuracy: 0.8154
# Epoch 38/50
# 5/5 [==============================] - 2s 467ms/step - loss: 0.1643 - accuracy: 0.9653 - val_loss: 0.6039 - val_accuracy: 0.8077
# Epoch 39/50
# 5/5 [==============================] - 2s 399ms/step - loss: 0.1954 - accuracy: 0.9363 - val_loss: 0.5324 - val_accuracy: 0.8385
# Epoch 40/50
# 5/5 [==============================] - 2s 381ms/step - loss: 0.1752 - accuracy: 0.9459 - val_loss: 0.5028 - val_accuracy: 0.8462
# Epoch 41/50
# 5/5 [==============================] - 2s 375ms/step - loss: 0.1445 - accuracy: 0.9633 - val_loss: 0.5245 - val_accuracy: 0.8231
# Epoch 42/50
# 5/5 [==============================] - 2s 401ms/step - loss: 0.1764 - accuracy: 0.9402 - val_loss: 0.4897 - val_accuracy: 0.8385
# Epoch 43/50
# 5/5 [==============================] - 2s 381ms/step - loss: 0.1535 - accuracy: 0.9517 - val_loss: 0.4736 - val_accuracy: 0.8538
# Epoch 44/50
# 5/5 [==============================] - 2s 447ms/step - loss: 0.1260 - accuracy: 0.9730 - val_loss: 0.4652 - val_accuracy: 0.8846
# Epoch 45/50
# 5/5 [==============================] - 2s 391ms/step - loss: 0.1264 - accuracy: 0.9710 - val_loss: 0.4484 - val_accuracy: 0.8615
# Epoch 46/50
# 5/5 [==============================] - 2s 407ms/step - loss: 0.1190 - accuracy: 0.9730 - val_loss: 0.4614 - val_accuracy: 0.8385
# Epoch 47/50
# 5/5 [==============================] - 2s 499ms/step - loss: 0.1267 - accuracy: 0.9653 - val_loss: 0.4736 - val_accuracy: 0.8462
# Epoch 48/50
# 5/5 [==============================] - 2s 385ms/step - loss: 0.0981 - accuracy: 0.9768 - val_loss: 0.4849 - val_accuracy: 0.8462
# Epoch 49/50
# 5/5 [==============================] - 2s 383ms/step - loss: 0.0990 - accuracy: 0.9768 - val_loss: 0.5137 - val_accuracy: 0.8462
# Epoch 50/50
# 5/5 [==============================] - 2s 423ms/step - loss: 0.0925 - accuracy: 0.9846 - val_loss: 0.5186 - val_accuracy: 0.8308

# %% [markdown]
# Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning. Now we will train our model on 50 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already reached a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %%
# Saving model
model.save("Bird species prediction")
# Out:
# INFO:tensorflow:Assets written to: Bird species prediction/assets
# INFO:tensorflow:Assets written to: Bird species prediction/assets

# %% [markdown]
# Now we will save the model in h5 format to use it later for prediction.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Next we will plot the accuracy of the model for the training history.

# %%
#Plot the loss history
plt.figure(figsize=(12, 5))
plt.plot(history.history['loss'], color='r')
plt.plot(history.history['val_loss'], color='b')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# Here we will plot the loss of the model for the training history.

# %%
# Calculating test accuracy
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# 6/6 [==============================] - 0s 30ms/step - loss: 0.4067 - accuracy: 0.8405
# Test Accuracy: 84.04908180236816

# %% [markdown]
# Evaluating the model to know the accuracy of the model on the test data.

# %%
# Storing predictions
y_pred = model.predict(x_test)
# Out:
# 6/6 [==============================] - 0s 30ms/step

# %% [markdown]
# Here we are storing prediction on test data.

# %%
# Plotting image to compare
img = array_to_img(x_test[5])
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %% [markdown]
# Visualizing one of the image which we will be further used for prediction.

# %%
# Finding max value from predition list and comaparing original value vs predicted
labels = lb.classes_
print(labels)
print("Originally : ",labels[np.argmax(y_test[5])])
print("Predicted : ",labels[np.argmax(y_pred[5])])
# Out:
# ['AMERICAN GOLDFINCH' 'BARN OWL' 'CARMINE BEE-EATER' 'DOWNY WOODPECKER'
#  'EMPEROR PENGUIN' 'FLAMINGO']
# Originally :  EMPEROR PENGUIN
# Predicted :  EMPEROR PENGUIN

# %% [markdown]
# Now, we will create list of labels using object of label binarizer. We will print that list and finally we will print out the prediction and the original label of the image we visualized above using argmax().

# %% [markdown]
# # Conclusion:

# %% [markdown]
# We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the bird species using the image supplied to model.

# %% [markdown]
# # Scope:

# %% [markdown]
# This project can be used for educational purposes to get a better understanding of how to create network architecture for a CNN model. You can further hyper parameter tune this model to reach a higher accuracy. It can be used by bird sanctuaries to identify different types of birds.
